# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

import geoviews.tile_sources as gvtiles#MY CODE ADDED
import geoviews as gv#MY CODE ADDED
from geoviews import tile_sources as gvtiles#MY CODE ADDED

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0       invercargill -46.4000  168.3500      5.01        84
# 1        1           coquimbo -29.9533  -71.3436     11.85        66
# 2        2           waitangi -43.9535 -176.5597      6.01        92
# 3        3              crane  31.3974 -102.3501     27.21        45
# 4        4  wailua homesteads  22.0669 -159.3780     26.44        81
#
#    Cloudiness  Wind Speed Country        Date
# 0          99        0.89      NZ  1693120791
# 1           0        1.03      CL  1693121063
# 2         100        5.87      NZ  1693121063
# 3          18        2.61      US  1693121063
# 4          75        8.23      US  1693121064

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

# %%
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    'Lng', 'Lat', geo=True, tiles="CartoLight",
    frame_width=800, frame_height=600,
    size='Humidity', scale=2, cmap='coolwarm',
    hover_cols=["City", "Humidity"]
)
# YOUR CODE HERE

# Display the map
map_plot# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Narrow down cities that fit criteria and drop any results with null values


ideal_weather_df = city_data_df[
    (city_data_df["Max Temp"] > 20) &  # Max temperature greater than °C
    (city_data_df["Max Temp"] < 30) &  # Max temperature less than °C
    (city_data_df["Humidity"] > 2) &  # Humidity more than %
    (city_data_df["Humidity"] < 60) &  # Humidity less than %
    (city_data_df["Wind Speed"] > 2) & # Wind speed more than m/s
    (city_data_df["Wind Speed"] < 10) & # Wind speed less than m/s
    (city_data_df["Cloudiness"] > 2) &  # Cloudiness more than %
    (city_data_df["Cloudiness"] < 25)   # Cloudiness less than %
]# YOUR CODE HERE

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()# YOUR CODE HERE

# Display sample data
ideal_weather_df# YOUR CODE HERE
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 3          3          crane  31.3974 -102.3501     27.21        45
# 5          5          altai  46.3722   96.2583     20.94        28
# 71        71          rieti  42.4072   12.8592     25.35        34
# 228      228         nyurba  63.2842  118.3319     25.68        34
# 247      247        tsiombe -25.3000   45.4833     28.30        36
# 258      258        maumere  -8.6199  122.2111     27.98        57
# 263      263  alice springs -23.7000  133.8833     26.75        11
# 360      360       vilyuysk  63.7553  121.6247     26.35        32
# 455      455      saynshand  44.8824  110.1163     27.39        22
# 477      477     balkanabat  39.5108   54.3671     27.47        24
# 494      494         vernon  50.2581 -119.2691     20.25        49
#
#      Cloudiness  Wind Speed Country        Date
# 3            18        2.61      US  1693121063
# 5            19        2.15      MN  1693121065
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df.copy()# YOUR CODE HERE

# Drop specified columns
columns_to_drop = ["City_ID", "Max Temp", "Cloudiness", "Wind Speed", "Date"]
hotel_df.drop(columns=columns_to_drop, inplace=True)# MY CODE ADDED

# Move "Country" column after "City" column
cols = list(hotel_df.columns)
cols.remove("Country")  # Remove "Country" from its current position
cols.insert(cols.index("City") + 1, "Country")  # Insert "Country" after "City"
hotel_df = hotel_df[cols]# MY CODE ADDED

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""# YOUR CODE HERE

# Display sample data
hotel_df# YOUR CODE HERE
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 3            crane      US  31.3974 -102.3501        45
# 5            altai      MN  46.3722   96.2583        28
# 71           rieti      IT  42.4072   12.8592        34
# 228         nyurba      RU  63.2842  118.3319        34
# 247        tsiombe      MG -25.3000   45.4833        36
# 258        maumere      ID  -8.6199  122.2111        57
# 263  alice springs      AU -23.7000  133.8833        11
# 360       vilyuysk      RU  63.7553  121.6247        32
# 455      saynshand      MN  44.8824  110.1163        22
# 477     balkanabat      TM  39.5108   54.3671        24
# 494         vernon      CA  50.2581 -119.2691        49

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
## Set parameters to search for a hotel
#radius = # YOUR CODE HERE
#params = {# YOUR CODE HERE
#}
#
## Print a message to follow up the hotel search
#print("Starting hotel search")
#
## Iterate through the hotel_df DataFrame
#for index, row in hotel_df.iterrows():
#    # get latitude, longitude from the DataFrame
#    # YOUR CODE HERE
#    
#    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
#    params["filter"] = # YOUR CODE HERE
#    params["bias"] = # YOUR CODE HERE
#    
#    # Set base URL
#    base_url = "https://api.geoapify.com/v2/places"
#
#
#    # Make and API request using the params dictionaty
#    name_address = # YOUR CODE HERE
#    
#    # Convert the API response to JSON format
#    name_address = # YOUR CODE HERE
#    
#    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
#    try:
#        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
#    except (KeyError, IndexError):
#        # If no hotel is found, set the hotel name as "No hotel found".
#        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
#        
#    # Log the search results
#    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
#
## Display sample data
#hotel_df

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "type": "accommodation.hotel",  # Updated to a supported category
    "limit": 5,
    "apiKey": geoapify_key  # Replace with your actual API key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    response_data = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_name = response_data["features"][0]["properties"]["name"]
        hotel_df.loc[index, "Hotel Name"] = hotel_name
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# crane - nearest hotel: No hotel found
# altai - nearest hotel: Altai hotel 40000-100000T
# rieti - nearest hotel: Hotel Miramonti
# nyurba - nearest hotel: Марина
# tsiombe - nearest hotel: No hotel found
# maumere - nearest hotel: Bogor
# alice springs - nearest hotel: Aurora Alice Springs
# vilyuysk - nearest hotel: Мария
# saynshand - nearest hotel: No hotel found
# balkanabat - nearest hotel: Nebitçi
# vernon - nearest hotel: Okanagan Royal Park Inn
#               City Country      Lat       Lng  Humidity  \
# 3            crane      US  31.3974 -102.3501        45
# 5            altai      MN  46.3722   96.2583        28
# 71           rieti      IT  42.4072   12.8592        34
# 228         nyurba      RU  63.2842  118.3319        34
# 247        tsiombe      MG -25.3000   45.4833        36
# 258        maumere      ID  -8.6199  122.2111        57
# 263  alice springs      AU -23.7000  133.8833        11
# ...

# %%
# # Set parameters to search for a hotel
# radius = 10000
# params = {
#     "type": "accommodation.hotel",  # Updated to a supported category
#     "limit": 1,
#     "apiKey": geoapify_key  # Replace with your actual API key
# }

# # Print a message to follow up the hotel search
# print("Starting hotel search")

# # Iterate through the hotel_df DataFrame
# for index, row in hotel_df.iterrows():
#     # Get latitude, longitude from the DataFrame
#     latitude = row["Lat"]
#     longitude = row["Lng"]

#     # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
#     params["lat"] = latitude
#     params["lon"] = longitude

#     # Set base URL
#     base_url = "https://api.geoapify.com/v2/places"

#     # Make an API request using the params dictionary
#     response = requests.get(base_url, params=params)

#     # Convert the API response to JSON format
#     response_data = response.json()

# response_data
# Out:
# Starting hotel search
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Okanagan Royal Park Inn',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'British Columbia',
#     'county': 'Regional District of North Okanagan',
#     'city': 'Vernon',
#     'postcode': 'V1T 9E5',
#     'street': '25 Avenue',
#     'housenumber': '3200',
#     'lon': -119.27409689882703,
#     'lat': 50.2602827,
#     'state_code': 'BC',
#     'formatted': 'Okanagan Royal Park Inn, 3200 25 Avenue, Vernon, BC V1T 9E5, Canada',
#     'address_line1': 'Okanagan Royal Park Inn',
#     'address_line2': '3200 25 Avenue, Vernon, BC V1T 9E5, Canada',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access'],
#     'details': ['details', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
# ...

# %%
# # Set the API key and endpoint
# api_key = geoapify_key
# base_url = "https://api.geoapify.com/v2/places"

# # Set the coordinates and other parameters
# latitude = 31.3974
# longitude = -102.3501
# radius = 10000
# category = "accommodation.hotel"
# limit = 1

# # Construct the parameters for the API request
# params = {
#     "lat": latitude,
#     "lon": longitude,
#     "type": category,
#     "limit": limit,
#     "apiKey": api_key
# }

# # Make the API request
# response = requests.get(base_url, params=params)

# # Convert the API response to JSON format
# data = response.json()

# # Print the response
# data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Mainstay Suites',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Texas',
#     'county': 'Ector County',
#     'city': 'Odessa',
#     'postcode': '79766',
#     'district': 'Humble',
#     'street': 'South Grant Avenue',
#     'housenumber': '1801',
#     'lon': -102.35352006148796,
#     'lat': 31.8265509,
#     'state_code': 'TX',
#     'formatted': 'Mainstay Suites, 1801 South Grant Avenue, Odessa, TX 79766, United States of America',
#     'address_line1': 'Mainstay Suites',
#     'address_line2': '1801 South Grant Avenue, Odessa, TX 79766, United States of America',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation'],
#     'details': ['details', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

# %%
# Configure the map plot
map_plot = hotel_df.hvplot.points(
    'Lng', 'Lat', geo=True, tiles=gvtiles.CartoLight,
    frame_width=800, frame_height=600,
    size='Humidity', scale=2, cmap='coolwarm',
    hover_cols=["City", "Humidity", "Hotel Name", "Country"]
)# YOUR CODE HERE

# Display the map
map_plot# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Hotel Name,Country)

# %%
pip install geoviews

# %%
pip install geoviews[recommended]
